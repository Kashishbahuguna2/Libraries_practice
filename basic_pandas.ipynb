# %%
# reading excel file 

import pandas as pd

df =  pd.read_csv("d:\sales_data_sample.csv" , encoding = "latin1")
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
import pandas as pd 
data ={"name" : ['ram' , 'rohan' ,'geeta'],
       "age" : [10,20,30],
       "city" : ['delhi' , 'mumbai' , 'nagpur']}
            
df = pd.DataFrame(data)
print(df)

df.to_json("output.json")
# Out:
#     name  age    city
# 0    ram   10   delhi
# 1  rohan   20  mumbai
# 2  geeta   30  nagpur

# %%
# head(n) { by default first 5 rows deta h }
# tail(n) {by default last 5 rows deta h }


import pandas as pd

df =  pd.read_csv("d:\sales_data_sample.csv" , encoding = "latin1")

print("the first 10 rows of data sample file \n")
print(df.head(10))
print("\nthe laast 10 rows of data sample file")
print(df.tail(10))
# Out:
# the first 10 rows of data sample file
#
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# ...

# %%
#info() method 
#1 number of rows and column  
#2 colunm name 
#3 data type 
#4 non null counts 
#5 memory usage 

import pandas as pd 
data ={"name" : ['ram' , 'rohan' ,'geeta'],
       "age" : [10,20,30],
       "city" : ['delhi' , 'mumbai' , 'nagpur']}
            
df = pd.DataFrame(data)

print("displaying tha info of data sample file ")
print(df.info())
# Out:
# displaying tha info of data sample file
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
# describe() method 

import pandas as pd 
data ={"name" : ['ram' , 'rohan' ,'geeta' ,'rahul' ,'sonam' ,'siya' ,'aman' ,'pooja'],
       "age" : [22 , 26 ,28,29,45,23,33,24],
       "salary" : [10000 ,50000,30000,400000,23000,900000,240000 , 700000]}
            
df = pd.DataFrame(data)
print(df)

print("displaying descriptive statistic")
print(df.describe())
# Out:
#     name  age  salary
# 0    ram   22   10000
# 1  rohan   26   50000
# 2  geeta   28   30000
# 3  rahul   29  400000
# 4  sonam   45   23000
# 5   siya   23  900000
# 6   aman   33  240000
# 7  pooja   24  700000
# displaying descriptive statistic
#              age         salary
# count   8.000000       8.000000
# mean   28.750000  294125.000000
# std     7.478541  344249.260815
# min    22.000000   10000.000000
# 25%    23.750000   28250.000000
# 50%    27.000000  145000.000000
# 75%    30.000000  475000.000000
# max    45.000000  900000.000000

# %%
'''
how big is your dataset?
what are name of column?
'''
# shape and column method 

import pandas as pd 
data ={"name" : ['ram' , 'rohan' ,'geeta' ,'rahul' ,'sonam' ,'siya' ,'aman' ,'pooja'],
       "age" : [22 , 26 ,28,29,45,23,33,24],
       "salary" : [10000 ,50000,30000,400000,23000,900000,240000 , 700000]}
            
df = pd.DataFrame(data)
print(f"shape : {df.shape}")
print(f"column name : {df.columns}")
# Out:
# shape : (8, 3)
# column name : Index(['name', 'age', 'salary'], dtype='object')

# %%
'''
SELECTING AND FILTERING 
1 select specific column 
2 filter rows 
3 combine multiple conditions 

SELECTING COLUMNS RETURNS 
1  a series
2  dataframe multiples column of data

column = df["column name")
subset = df["column1name" , "column2name"]

FILTERING ROWS 
1 booleand indexing
##based on single condition 
filtered_rows = df[df["column name "]>value]
## based on multiple condition
filtersd_rows = df[(df["column name"]>value ),(df["column name "<vlaue ])]
 '''

import pandas as pd 
data ={"name" : ['ram' , 'rohan' ,'geeta' ,'rahul' ,'sonam' ,'siya' ,'aman' ,'pooja'],
       "age" : [22 , 26 ,28,29,45,23,33,24],
       "salary" : [10000 ,50000,30000,400000,23000,900000,240000 , 700000]}
            
df = pd.DataFrame(data)

filtering = df[(df["salary"]>30000) ]
filtering1 = df[(df["salary"]>30000) & (df["age"]>23)] # by using and condition 
filtering2 = df[(df["salary"]>30000) | (df["age"]>22)] # by using or condition 
print(filtering )
print(filtering1 )
print(filtering2 )
# Out:
#     name  age  salary
# 1  rohan   26   50000
# 3  rahul   29  400000
# 5   siya   23  900000
# 6   aman   33  240000
# 7  pooja   24  700000
#     name  age  salary
# 1  rohan   26   50000
# 3  rahul   29  400000
# 6   aman   33  240000
# 7  pooja   24  700000
#     name  age  salary
# 1  rohan   26   50000
# 2  geeta   28   30000
# 3  rahul   29  400000
# 4  sonam   45   23000
# 5   siya   23  900000
# 6   aman   33  240000
# 7  pooja   24  700000
